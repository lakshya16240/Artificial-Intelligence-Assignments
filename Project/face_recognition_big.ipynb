# %%
import matplotlib.image as img
import os
import numpy
import numpy.linalg
from sklearn.svm import SVC
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from skimage import data, exposure, img_as_float

print("hello")

# imagesList = os.listdir("/Users/lakshya/Desktop/Lakshya/Artificial Intelligence/AI Project/yalefaces/")
# imagesList = imagesList[1:]
# imagesList = numpy.array(imagesList)
# numpy.random.shuffle(imagesList)
# print(imagesList.__getitem__(0))
# for i in range(imagesList.shape[0]):
#     print(imagesList[i])
# Out:
# hello

# %%
y=[]
x =[]
path = "/mnt/d/College/Semester-5/AI_ArtificialIntelligence/ExtendedYaleB/YaleB"
for i in range(11,25):
    print(i)
    if i != 14:
        personPath = path + str(i) + "/"
#         print(personPath)
        yaleBImagesList = os.listdir(personPath)
#         yaleBImagesList = yaleBImagesList[2:]
        yaleBImagesList = numpy.array(yaleBImagesList)
        yaleBImagesList = yaleBImagesList[:361]
        numpy.random.shuffle(yaleBImagesList)
        for j in range(yaleBImagesList.__len__()):
            print("j " + str(j))
            t = exposure.equalize_hist(img.imread(personPath + yaleBImagesList[i])).flatten()
            x.append(t/numpy.linalg.norm(t))
            y.append("person" + str(i))

x = numpy.array(x)
print(x.shape[0])
# Out:
# 11
# j 0
# j 1
# j 2
# j 3
# j 4
# j 5
# j 6
# j 7
# j 8
# j 9
# j 10
# j 11
# j 12
# j 13
# j 14
# j 15
# j 16
# j 17
# j 18
# j 19
# j 20
# j 21
# j 22
# j 23
# j 24
# j 25
# j 26
# j 27
# j 28
# j 29
# j 30
# j 31
# j 32
# j 33
# j 34
# j 35
# j 36
# j 37
# j 38
# j 39
# j 40
# j 41
# j 42
# j 43
# j 44
# j 45
# j 46
# j 47
# j 48
# j 49
# j 50
# j 51
# j 52
# j 53
# j 54
# j 55
# j 56
# j 57
# j 58
# j 59
# j 60
# j 61
# j 62
# j 63
# j 64
# j 65
# j 66
# j 67
# j 68
# j 69
# j 70
# j 71
# j 72
# j 73
# j 74
# j 75
# j 76
# j 77
# j 78
# j 79
# j 80
# j 81
# j 82
# j 83
# j 84
# j 85
# j 86
# j 87
# j 88
# j 89
# j 90
# j 91
# j 92
# j 93
# j 94
# j 95
# j 96
# j 97
# j 98
# j 99
# j 100
# j 101
# j 102
# j 103
# j 104
# j 105
# j 106
# j 107
# j 108
# j 109
# j 110
# j 111
# j 112
# j 113
# j 114
# j 115
# j 116
# j 117
# j 118
# j 119
# j 120
# j 121
# j 122
# j 123
# j 124
# j 125
# j 126
# j 127
# j 128
# j 129
# j 130
# j 131
# j 132
# j 133
# j 134
# j 135
# j 136
# j 137
# ...

# %%
# print(x.shape[0]

# %%
y = numpy.array(y)

test_x = x[int(0.7 * x.shape[0]):]
train_x = x[ : int(0.7 * x.shape[0])]

test_y = y[int(0.7 * y.shape[0]):]

# for i in range(test_y.size):
#     print(test_y[i])

train_y = y[ : int(0.7 * y.shape[0])]

param_grid = {'C': [1e3, 5e3, 1e5],'gamma': [0.0001, 0.001, 0.01]} 
clf = GridSearchCV(SVC(), param_grid)

clf.fit(train_x,train_y)
predicted_y = clf.predict(test_x)

# for i in range(test_y.shape[0]):
#     print(predicted_y[i]," ",test_y[i],"\n")

print(accuracy_score(test_y, predicted_y))

print(y.shape[0])
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.23082386363636365
# 4693
